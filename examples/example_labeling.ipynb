# %%
import dlc_manager as dlm

# %%
project_root_path = r'Absolute\path\for\project\root'

# %%
prj = dlm.init_data_project(project_root_path)
# Out:
# ⏭  Store already initialized: C:\Users\Egor\Desktop\DLC_prod\frames_store
# ⏭  Inference store already initialized: C:\Users\Egor\Desktop\DLC_prod\inference_runs

# %%
prj.list_extractions()
# Out:
# {'WIN_video_extraction_DEFAULT': {'video_path': 'C:\\Users\\Egor\\Desktop\\DLC_prod\\raw_videos\\My_folder_1\\WIN_20260921_18_17_20_Pro.mp4',
#   'video_stem': 'WIN_20260921_18_17_20_Pro',
#   'config_name': 'default',
#   'config': {'name': 'default',
#    'algo': 'kmeans',
#    'mode': 'automatic',
#    'userfeedback': False,
#    'numframes2pick': 20,
#    'start': 0.0,
#    'stop': 1.0,
#    'engine': 'pytorch'},
#   'frame_count': 20,
#   'project_config': 'C:\\Users\\Egor\\Desktop\\DLC_prod\\frames_store\\labeled-data\\WIN_video_extraction_DEFAULT\\config.yaml',
#   'updated_at': '2026-09-21T19:33:44'},
#  'WIN_video_extraction_DENSE': {'video_path': 'C:\\Users\\Egor\\Desktop\\DLC_prod\\raw_videos\\My_folder_1\\WIN_20260921_18_17_20_Pro.mp4',
#   'video_stem': 'WIN_20260921_18_17_20_Pro',
#   'config_name': 'dense_sampling',
#   'config': {'name': 'dense_sampling',
#    'algo': 'kmeans',
#    'mode': 'automatic',
#    'userfeedback': False,
#    'numframes2pick': 50,
# ...

# %%
path_default = 'Choosen_folder_name_1'

# %%
prj.init_labeling_config(path_default,'Egor',
    bodyparts=[
        "thumb_tip", "index_tip","middle_tip", "ring_tip","pinky_tip","palm_center"
    ],
    skeleton=[
        ["thumb_tip", "palm_center"],
        ["index_tip", "palm_center"],
        ["middle_tip", "palm_center"],
        ["ring_tip", "palm_center"],
        ["pinky_tip", "palm_center"]
    ],)
# Out:
# ✅ Labeling schema set: C:\Users\Egor\Desktop\DLC_prod\frames_store\labeled-data\WIN_video_extraction_DEFAULT\config.yaml
# WindowsPath('C:/Users/Egor/Desktop/DLC_prod/frames_store/labeled-data/WIN_video_extraction_DEFAULT/config.yaml')

# %%
prj.label_frames_for(path_default)
# Out:
# c:\Users\Egor\anaconda3\envs\DLC_prod\Lib\site-packages\napari_deeplabcut\core\io.py:208: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   temp.stack(["individuals", "bodyparts"])
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1068+0+79 (frame: 1938x1115-9+41) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1001+0+79 (frame: 1938x1048-9+41) margins: 9, 38, 9, 9 minimum size: 594x854 MINMAXINFO(maxSize=POINT(x=0, y=0), maxpos=POINT(x=0, y=0), maxtrack=POINT(x=0, y=0), mintrack=POINT(x=761, y=1115)))
